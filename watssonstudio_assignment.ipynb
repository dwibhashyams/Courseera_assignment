# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shankar Dwibhashyam**
#
# Data Analyst

# %% [markdown]
# *I am interested in data science because i need to use these metrics for electrical manfacturing industry*

# %% [markdown]
# ### Simple addition of a & b

# %%
a=input("enter value of a")
b= input("enter value of b")
sum= int(a) + int(b)
print("sum of two numbers a+b is",sum)
# Out:
# enter value of a2
# enter value of b2
# sum of two numbers a+b is 4

# %% [markdown]
# + interger
# - strings
# - boolean

# %% [markdown]
# ![Road%20map.jpeg](attachment:Road%20map.jpeg)

# %% [markdown]
# ~~strikethrouh~~

# %% [markdown]
# [git_hub](https://github.com/dwibhashyams/Courseera_assignment)

# %% [markdown]
# #### HTML link
